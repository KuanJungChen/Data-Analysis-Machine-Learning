# %%
import googlemaps
import pandas as pd
import requests

# %%
#公開資料API
garbage_data = requests.get('https://data.taipei/api/getDatasetInfo/downloadResource?id=6bb3304b-4f46-4bb0-8cd1-60c66dcd1cae&rid=fa880d09-adc6-4527-bbb8-3514a52950a6')

# %%
garbage_data
# Out:
# <Response [200]>

# %%
garbage_data.json()
# Out:
# [{'行政區': '萬華區',
#   '里別': '富福里',
#   '分隊': '昆明分隊',
#   '局編': '101-041',
#   '路線': '昆明1-1',
#   '車次': '第1車',
#   '抵達時間': 1710,
#   '離開時間': 1725,
#   '地點': '臺北市萬華區和平西路三段120號(行政中心)',
#   '緯度': 121.499869,
#   '經度': 25.035029,
# ...

# %%
pd.DataFrame(garbage_data.json())
# Out:
#       行政區   里別    分隊       局編     路線   車次  抵達時間  離開時間                      地點  \
# 0     萬華區  富福里  昆明分隊  101-041  昆明1-1  第1車  1710  1725  臺北市萬華區和平西路三段120號(行政中心)
# 1     萬華區  仁德里  昆明分隊  101-041  昆明1-1  第1車  1735  1738            臺北市萬華區桂林路41號
# 2     萬華區  富民里  昆明分隊  101-041  昆明1-1  第1車  1740  1743           臺北市萬華區桂林路101號
# 3     萬華區  青山里  昆明分隊  101-041  昆明1-1  第1車  1745  1749          臺北市萬華區桂林路137號前
# 4     萬華區  柳鄉里  昆明分隊  101-041  昆明1-1  第1車  1756  1758        臺北市萬華區環河南路二段48號前
# ...   ...  ...   ...      ...    ...  ...   ...   ...                     ...
# 4011  士林區  富洲里  社子分隊   99-013  社子6-2  第2車  2121  2126       臺北市士林區延平北路八段55巷1號
# 4012  士林區  福安里  社子分隊   99-013  社子6-2  第2車  2127  2134        臺北市士林區延平北路七段261號
# 4013  士林區  福安里  社子分隊   99-013  社子6-2  第2車  2135  2138        臺北市士林區延平北路七段149號
# 4014  士林區  福安里  社子分隊   99-013  社子6-2  第2車  2139  2142        臺北市士林區延平北路七段125號
# 4015  士林區  福安里  社子分隊   99-013  社子6-2  第2車  2143  2146         臺北市士林區延平北路七段85號
#
# ...

# %%
#網站API存取
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
hahow_data = requests.get("https://api.hahow.in/api/courses?limit=30", headers=headers)
hahow_data.json()
# Out:
# {'_metadata': {'page': 0, 'count': 579},
#  'data': [{'successCriteria': {'numSoldTickets': 30},
#    'campaign': {'types': []},
#    'numSoldTickets': 25,
#    'status': 'INCUBATING',
#    'reviewing': False,
#    'price': 3200,
#    'preOrderedPrice': 2400,
#    'isReject': False,
#    'averageRating': 0,
#    'numRating': 0,
#    'tags': ['END_OF_INCUBATING'],
#    '_id': '5fe22e7fe810e10fc483dd78',
#    'owner': {'_id': '5d536d5cdc1b9100216aa7ed',
#     'name': '古君葳',
#     'username': 'pk74323jacky',
#     'profileImageUrl': 'https://images.api.hahow.in/images/5eb83d58df216899c0d400d0'},
#    'uniquename': 'springboot',
#    'estimatedCourseStartTime': '2021-04-19T16:00:00.000Z',
#    'incubateTime': '2021-01-20T04:00:20.761Z',
#    'proposalDueTime': '2021-02-18T16:00:00.000Z',
#    'modules': ['5fe7001ae810e10b8b89192e',
#     '5fe705e2f2dd3144f10a2c24',
#     '5fe70b63f2dd31f7f30a3180',
#     '5fe70b77f2dd316c7c0a319d',
#     '5fe70cbbe810e114c4892a84',
# ...

# %%
pd.DataFrame(hahow_data.json()['data'])
# Out:
#             successCriteria  \
# 0    {'numSoldTickets': 30}
# 1    {'numSoldTickets': 60}
# 2    {'numSoldTickets': 30}
# 3    {'numSoldTickets': 30}
# 4    {'numSoldTickets': 30}
# 5    {'numSoldTickets': 30}
# 6    {'numSoldTickets': 30}
# 7    {'numSoldTickets': 30}
# 8    {'numSoldTickets': 30}
# 9    {'numSoldTickets': 30}
# 10   {'numSoldTickets': 30}
# 11   {'numSoldTickets': 50}
# 12   {'numSoldTickets': 30}
# 13  {'numSoldTickets': 100}
# 14   {'numSoldTickets': 50}
# 15   {'numSoldTickets': 30}
# 16   {'numSoldTickets': 30}
# 17   {'numSoldTickets': 30}
# 18   {'numSoldTickets': 30}
# 19   {'numSoldTickets': 30}
# 20   {'numSoldTickets': 30}
# 21   {'numSoldTickets': 30}
# 22   {'numSoldTickets': 40}
# 23   {'numSoldTickets': 30}
# 24   {'numSoldTickets': 50}
# 25   {'numSoldTickets': 30}
# 26   {'numSoldTickets': 30}
# 27   {'numSoldTickets': 30}
# 28   {'numSoldTickets': 30}
# 29   {'numSoldTickets': 30}
#
# ...

# %%
import googlemaps
import time

# %%
#google maps api 取得地理位置
from datetime import datetime
gmaps = googlemaps.Client(key='AIzaSyCTa8U3tPGe7Ds14J46qlA7xbIgO4mcJUo')

# %%
cities = ['臺北市','新北市','桃園市','臺中市','臺南市','高雄市','新竹縣',
          '苗栗縣','彰化縣','南投縣','雲林縣','嘉義縣','屏東縣','宜蘭縣',
          '花蓮縣','臺東縣','澎湖縣','金門縣','連江縣','基隆市','新竹市',
          '嘉義市']

# %%
#地理位置轉成經緯度
geocode_result = gmaps.geocode('臺北市')
geocode_result
# Out:
# [{'address_components': [{'long_name': 'Taipei',
#     'short_name': 'Taipei',
#     'types': ['colloquial_area', 'locality', 'political']},
#    {'long_name': 'Taiwan',
#     'short_name': 'TW',
#     'types': ['country', 'political']}],
#   'formatted_address': 'Taipei, Taiwan',
#   'geometry': {'bounds': {'northeast': {'lat': 25.2443731, 'lng': 121.7300824},
#     'southwest': {'lat': 24.7900797, 'lng': 121.2826735}},
#    'location': {'lat': 25.0329694, 'lng': 121.5654177},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 25.2443731, 'lng': 121.7300824},
#     'southwest': {'lat': 24.7900797, 'lng': 121.2826735}}},
#   'place_id': 'ChIJmQrivHKsQjQR4MIK3c41aj8',
#   'types': ['colloquial_area', 'locality', 'political']}]

# %%
loc = geocode_result[0]['geometry']['location']
loc
# Out:
# {'lat': 25.0329694, 'lng': 121.5654177}

# %%
#places_nearby一次只會回傳20間店家資料，必須用裡面的next_page_token再去拿下一間的20間店家資料
gmaps.places_nearby(location=loc,radius=25000, keyword="寵物")
# Out:
# {'html_attributions': [],
#  'next_page_token': 'ATtYBwLVQNtx8b3kgjNlO-F5GypgM2DuDSaZzsi4bm_1iS2jjwdE9jIBenta9EjchYUOSwnup8vcW5xNWj8MjMMdgH1Styb-ZDgccDAddU0LkEjEQCKDQOur6dtu4jF13liurE2NpG10vPl1j_hfPVmomBz96W6svf1tNqVMiFuRZvMcKmZUdFpr6H8Lun4FNJ-NzOZgJkHG9qbp01spBVPOjqDy2JXPJFHcqL_WdrGnkWcfiFeEfqt4vQj4hpmkACdh6she99CGifK1AiDkvmHgc8IGbn1kh2CjZ6RwwIS3W9uRwZNMLsmHtT3gmjOvJq3Dx0Xfut0rUGJSrCiylV-w6S6d4xJrpAelqz8OcjSyRlzaFS8IgbnRvAXlHEB2WvjZeruu1OgMTxld9eEa5oY4e4VooDSTCODNjNYD1AHuiC9tVXIl2EitdAs',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 23.4731801, 'lng': 120.4542569},
#     'viewport': {'northeast': {'lat': 23.47452057989272,
#       'lng': 120.4554977798927},
#      'southwest': {'lat': 23.47182092010728, 'lng': 120.4527981201073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': '汪旺來寵物生活館吳鳳店',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 5312,
# ...

# %%
ids = []
for city in cities:
    geocode_result = gmaps.geocode(city)
    loc = geocode_result[0]['geometry']['location']
    print("以"+city+"為中心半徑25000公尺的寵物店家數量:"
          +str(len(gmaps.places_nearby(keyword="寵物",location=loc,radius=25000)['results'])))
    results.extend(query_result['results'])
    for place in gmaps.places_nearby(keyword="寵物",location=loc,radius=25000)['results']:
        ids.append(place['place_id'])
# Out:
# 以臺北市為中心半徑25000公尺的寵物店家數量:20
# 以新北市為中心半徑25000公尺的寵物店家數量:20
# 以桃園市為中心半徑25000公尺的寵物店家數量:20
# 以臺中市為中心半徑25000公尺的寵物店家數量:20
# 以臺南市為中心半徑25000公尺的寵物店家數量:20
# 以高雄市為中心半徑25000公尺的寵物店家數量:20
# 以新竹縣為中心半徑25000公尺的寵物店家數量:20
# 以苗栗縣為中心半徑25000公尺的寵物店家數量:20
# 以彰化縣為中心半徑25000公尺的寵物店家數量:20
# 以南投縣為中心半徑25000公尺的寵物店家數量:20
# 以雲林縣為中心半徑25000公尺的寵物店家數量:20
# 以嘉義縣為中心半徑25000公尺的寵物店家數量:20
# 以屏東縣為中心半徑25000公尺的寵物店家數量:20
# 以宜蘭縣為中心半徑25000公尺的寵物店家數量:20
# 以花蓮縣為中心半徑25000公尺的寵物店家數量:20
# 以臺東縣為中心半徑25000公尺的寵物店家數量:20
# 以澎湖縣為中心半徑25000公尺的寵物店家數量:20
# 以金門縣為中心半徑25000公尺的寵物店家數量:20
# 以連江縣為中心半徑25000公尺的寵物店家數量:0
# 以基隆市為中心半徑25000公尺的寵物店家數量:20
# 以新竹市為中心半徑25000公尺的寵物店家數量:20
# 以嘉義市為中心半徑25000公尺的寵物店家數量:20

# %%
ids = []
for city in cities:
    results = []
    geocode_result = gmaps.geocode(city)
    loc = geocode_result[0]['geometry']['location']
    query_result = gmaps.places_nearby(keyword="寵物",location=loc, radius=10000)
    results.extend(query_result['results'])
    while query_result.get('next_page_token'):
        time.sleep(2)
        query_result = gmaps.places_nearby(page_token=query_result['next_page_token'])
        results.extend(query_result['results'])
        print("找到以"+city+"為中心半徑10000公尺的寵物店家數量(google maps api上限提供60間): "+str(len(results)))
        for place in results:
            ids.append(place['place_id'])
# Out:
# 找到以臺北市為中心半徑10000公尺的寵物店家數量(google mapi api上限提供60間): 40
# 找到以臺北市為中心半徑10000公尺的寵物店家數量(google mapi api上限提供60間): 60
# 找到以新北市為中心半徑10000公尺的寵物店家數量(google mapi api上限提供60間): 40
# 找到以新北市為中心半徑10000公尺的寵物店家數量(google mapi api上限提供60間): 60
# 找到以桃園市為中心半徑10000公尺的寵物店家數量(google mapi api上限提供60間): 40
# 找到以桃園市為中心半徑10000公尺的寵物店家數量(google mapi api上限提供60間): 60
# 找到以臺中市為中心半徑10000公尺的寵物店家數量(google mapi api上限提供60間): 40
# 找到以臺中市為中心半徑10000公尺的寵物店家數量(google mapi api上限提供60間): 60
# 找到以臺南市為中心半徑10000公尺的寵物店家數量(google mapi api上限提供60間): 40
# 找到以臺南市為中心半徑10000公尺的寵物店家數量(google mapi api上限提供60間): 60
# 找到以高雄市為中心半徑10000公尺的寵物店家數量(google mapi api上限提供60間): 40
# 找到以高雄市為中心半徑10000公尺的寵物店家數量(google mapi api上限提供60間): 60
# 找到以新竹縣為中心半徑10000公尺的寵物店家數量(google mapi api上限提供60間): 40
# 找到以新竹縣為中心半徑10000公尺的寵物店家數量(google mapi api上限提供60間): 60
# 找到以苗栗縣為中心半徑10000公尺的寵物店家數量(google mapi api上限提供60間): 35
# 找到以彰化縣為中心半徑10000公尺的寵物店家數量(google mapi api上限提供60間): 40
# 找到以彰化縣為中心半徑10000公尺的寵物店家數量(google mapi api上限提供60間): 60
# ...

# %%
gmaps.place(place_id = 'ChIJmQrivHKsQjQR4MIK3c41aj8',language='zh-TW')['result']
# Out:
# {'address_components': [{'long_name': '台北',
#    'short_name': '台北',
#    'types': ['colloquial_area', 'locality', 'political']},
#   {'long_name': '台灣', 'short_name': 'TW', 'types': ['country', 'political']}],
#  'adr_address': '<span class="country-name">台灣</span>台北',
#  'formatted_address': '台灣台北',
#  'geometry': {'location': {'lat': 25.0329694, 'lng': 121.5654177},
#   'viewport': {'northeast': {'lat': 25.24437305075871,
#     'lng': 121.730082426945},
#    'southwest': {'lat': 24.79007967254639, 'lng': 121.2826734839207}}},
#  'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/geocode-71.png',
#  'name': '台北',
#  'photos': [{'height': 1800,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114534778094234831332">Naveen Kumar Kotta</a>'],
# ...

# %%
stores_info=[]
#去除重複id
ids=list(set(ids))
for i,id in enumerate(ids):
    if i%100 == 0:
        print('progress:'+str(i)+"of"+str(len(ids)))
    stores_info.append(gmaps.place(place_id=id,language='zh-TW')['result'])
# Out:
# progress:0of969
# progress:100of969
# progress:200of969
# progress:300of969
# progress:400of969
# progress:500of969
# progress:600of969
# progress:700of969
# progress:800of969
# progress:900of969

# %%
stores_info[0:3]
# Out:
# [{'address_components': [{'long_name': '243號',
#     'short_name': '243號',
#     'types': ['street_number']},
#    {'long_name': '健康路', 'short_name': '健康路', 'types': ['route']},
#    {'long_name': '自強里',
#     'short_name': '自強里',
#     'types': ['administrative_area_level_4', 'political']},
#    {'long_name': '松山區',
#     'short_name': '松山區',
#     'types': ['administrative_area_level_3', 'political']},
#    {'long_name': '台北市',
#     'short_name': '台北市',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '台灣', 'short_name': 'TW', 'types': ['country', 'political']},
#    {'long_name': '105', 'short_name': '105', 'types': ['postal_code']}],
#   'adr_address': '<span class="postal-code">105</span><span class="country-name">台灣</span><span class="region">台北市</span><span class="locality">松山區</span><span class="street-address">自強里健康路243號</span>',
#   'business_status': 'OPERATIONAL',
#   'formatted_address': '105台灣台北市松山區健康路243號',
# ...

# %%
output = pd.DataFrame.from_dict(stores_info)

# %%
output
# Out:
#                                     address_components  \
# 0    [{'long_name': '243號', 'short_name': '243號', '...
# 1    [{'long_name': '733號', 'short_name': '733號', '...
# 2    [{'long_name': '東衛里', 'short_name': '東衛里', 'ty...
# 3    [{'long_name': '90', 'short_name': '90', 'type...
# 4    [{'long_name': '91號', 'short_name': '91號', 'ty...
# ..                                                 ...
# 964  [{'long_name': '402-3號', 'short_name': '402-3號...
# 965  [{'long_name': '19號', 'short_name': '19號', 'ty...
# 966  [{'long_name': '5', 'short_name': '5', 'types'...
# 967  [{'long_name': '707號', 'short_name': '707號', '...
# 968  [{'long_name': '21號', 'short_name': '21號', 'ty...
#
#                                            adr_address business_status  \
# 0    <span class="postal-code">105</span><span clas...     OPERATIONAL
# 1    <span class="postal-code">970</span><span clas...     OPERATIONAL
# 2    <span class="postal-code">880</span><span clas...     OPERATIONAL
# ...

# %%
print(output['geometry'][1])
# Out:
# {'location': {'lat': 23.9773248, 'lng': 121.5912227}, 'viewport': {'northeast': {'lat': 23.9784867302915, 'lng': 121.5928904802915}, 'southwest': {'lat': 23.9757887697085, 'lng': 121.5901925197085}}}

# %%
#地理位置轉成經緯度
geocode_result = gmaps.geocode('1600 Amphitheatre Parkway, Mountain View, CA')

#經緯度轉成地址
reverse_geocode_result = gmaps.reverse_geocode((40.714224, -73.961452))

#導航資訊，出發地、目的地、模式、出發時間
now = datetime.now()
directions_result = gmaps.directions("Sydney Town Hall",
                                     "Parramatta, NSW",
                                     mode="transit",
                                     departure_time=now)
